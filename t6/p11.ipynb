# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
plt.figure(figsize=(17, 6))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
df['target'].value_counts().plot(kind='bar',color=['salmon','lightblue'])
# Out:
# <Axes: xlabel='target'>

# %%
sns.countplot(x='sex', hue='target', data=df, palette='bwr')
plt.xticks([1,0],['Male','Female'])
# Out:
# ([<matplotlib.axis.XTick at 0x1b523739490>,
# ...
#  [Text(1, 0, 'Male'), Text(0, 0, 'Female')])

# %%
sns.displot(df['age'],bins=20)

# %%
df['cp'].value_counts().plot(kind='bar',color=['salmon','lightblue','lightgreen','pink'])
# Out:
# <Axes: xlabel='cp'>

# %%
sns.countplot(x='cp', hue='target', data=df, palette='bwr')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
g = sns.FacetGrid(df, hue ='target')
g.map(sns.kdeplot,'trestbps')
